# %%
from google.colab import drive
drive.mount('/content/gdrive')
data_path = '/content/gdrive/MyDrive/Final Dataset/articles/'

# %%
# Go to Shared With Me -> Final Dataset
# In the dropdown menu, press "Add shortcut to Drive" then choose MyDrive
import os
os.listdir('/content/gdrive/MyDrive/Final Dataset/articles/')
# This code cell should list out dataset files

# %%
import pandas as pd
import numpy as np
import re
article_data = pd.read_csv(data_path + 'dataset.csv')

# %%
# %%bash
# pip install tqdm boto3 requests regex sentencepiece sacremoses
# pip install transformers

# %%
from transformers import BertTokenizer, BertModel

bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertModel.from_pretrained("bert-base-uncased")

# %%
article_data['sentences'] = article_data['content'].apply(lambda x: sent_tokenize(str(x)))
article_data = article_data.to_numpy()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(max_depth=2, random_state=0)
